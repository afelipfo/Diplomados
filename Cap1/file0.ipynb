# %% [markdown]
# # 🐍 Introducción a Python
#
# Python es uno de los lenguajes de programación más populares y versátiles, especialmente en el campo de la ciencia de datos y la inteligencia artificial.
#
# Este notebook cubre:
#
# - Breve historia del lenguaje
# - Aplicaciones en IA y ciencia de datos
# - Ventajas frente a otros lenguajes
# - Entornos de trabajo recomendados

# %% [markdown]
# ## 📜 Breve historia
#
# - Python fue creado a finales de los años 80 por **Guido van Rossum**.
# - Su primera versión pública apareció en **1991**.
# - Fue diseñado para ser legible, simple y productivo.
# - El nombre "Python" no viene del animal 🐍, sino del grupo cómico "Monty Python".
#
# ### Evolución:
# - Python 2.x: soporte hasta 2020.
# - Python 3.x: versión actual con mejoras sustanciales (f-strings, typing, etc.).

# %% [markdown]
# ## 🧠 Aplicaciones en Ciencia de Datos e IA
#
# Python es el lenguaje **predilecto** en IA debido a su simplicidad y la enorme cantidad de librerías.
#
# ### Principales áreas de aplicación:
#
# - **Ciencia de datos**: análisis estadístico, visualización, minería de datos.
# - **Machine Learning**: clasificación, regresión, clustering.
# - **Deep Learning**: visión computacional, procesamiento de lenguaje natural.
# - **Automatización**: scripts, bots, scraping.
# - **Simulación y robótica**: entornos virtuales, control de sensores.
# - **Desarrollo web**: APIs con FastAPI, Flask o Django.
#
# ### Librerías destacadas:
# - `NumPy`, `Pandas`, `Matplotlib`, `Scikit-learn`
# - `TensorFlow`, `Keras`, `PyTorch`, `Transformers`

# %% [markdown]
# ## ⚙️ Ventajas de Python para ingeniería de IA
#
# - **Sintaxis sencilla**: ideal para principiantes y expertos.
# - **Amplio ecosistema de librerías**: soporte para todas las etapas de un proyecto.
# - **Gran comunidad**: foros, proyectos, cursos, eventos.
# - **Interoperabilidad**: puede integrarse con C++, Java, R, etc.
# - **Soporte para notebooks interactivos** (Jupyter, Colab).
#
# 👉 Es un lenguaje con curva de aprendizaje rápida pero con capacidad profesional para producción.

# %% [markdown]
# ## 💻 Entornos recomendados
#
# ### 🟦 Visual Studio Code (VS Code)
# - Editor ligero, multiplataforma.
# - Extensiones para Python, Jupyter, Git, Docker, etc.
#
# ### 📓 Jupyter Notebooks
# - Ideal para ciencia de datos, prototipos y experimentación.
# - Permite mezclar texto (Markdown), gráficos y código ejecutable.
#
# ### ☁️ Google Colab
#
#     Jupyter Notebooks en la nube.
#
#     No requiere instalación.
#
#     Incluye GPU/TPU gratis para entrenamiento de modelos.
#
# 🔗 https://colab.research.google.com
#
# ```python
# # Prueba rápida en una celda de Jupyter
# print("¡Hola desde Jupyter! 👋")

# %% [markdown]
# ---
#
# ## ✅ Conclusión
#
# ```markdown
# Python es el lenguaje más accesible y poderoso para trabajar en IA y ciencia de datos.
# Este curso/notebook te enseñará a dominarlo progresivamente, desde los conceptos básicos hasta temas avanzados como modelos generativos y despliegue en la nube.
#
# 🚀 ¡Comencemos!
