# %% [markdown]
# # 📂 1.4 Control de Versiones con Git y GitHub
#
# Este notebook presenta los conceptos fundamentales para trabajar con **Git** y **GitHub**, esenciales en proyectos colaborativos de ciencia de datos e inteligencia artificial.
#
# ## Temas:
# - Uso básico de Git y GitHub
# - Seguimiento de código, ramas y colaboración
# - Buenas prácticas para estructura de proyectos reproducibles

# %% [markdown]
# ## 🧰 1.4.1 ¿Qué es Git y para qué sirve?

# %% [markdown]
# Git es un sistema de control de versiones distribuido que permite:
#
# - Rastrear los cambios realizados en archivos de código y datos.
# - Volver a estados anteriores si es necesario.
# - Trabajar en equipo sin conflictos.
# - Automatizar tareas como pruebas y despliegue.
#
# GitHub es una plataforma basada en la nube que facilita la colaboración mediante repositorios Git.

# %% [markdown]
# ## 🛠️ 1.4.2 Comandos básicos de Git

# %% [markdown]
# A continuación, una tabla con comandos comunes:
#
# | Comando                       | Descripción                                  |
# |------------------------------|----------------------------------------------|
# | `git init`                   | Inicializa un repositorio local              |
# | `git clone <url>`            | Clona un repositorio remoto                  |
# | `git status`                 | Muestra los cambios actuales                 |
# | `git add <archivo>`          | Añade archivos al área de preparación        |
# | `git commit -m "mensaje"`    | Guarda los cambios con un mensaje            |
# | `git push`                   | Envía los commits al repositorio remoto      |
# | `git pull`                   | Actualiza el repo local con los cambios remotos |
# | `git checkout -b <rama>`     | Crea una nueva rama y cambia a ella          |

# %% [markdown]
# ### 👇 Ejecuta estos comandos desde tu terminal, no en Jupyter
#
# git init
#
# git add notebook.ipynb
#
# git commit -m "Primer commit del notebook"

# %% [markdown]
# ## 🌱 1.4.3 Uso de ramas para trabajo colaborativo

# %% [markdown]
# Las ramas te permiten trabajar en nuevas características sin afectar la rama principal (`main` o `master`).
#
# ```bash
# git checkout -b analisis-modelo

# %% [markdown]
# Luego puedes fusionarla con:

# %% [markdown]
# git checkout main
#
# git merge analisis-modelo

# %% [markdown]
# También puedes subir tu rama con:

# %% [markdown]
# git push origin analisis-modelo

# %% [markdown]
# ---
#
# ## 🧾 1.4.4 Estructura recomendada de carpetas
#
# ```markdown
# Un proyecto reproducible debe tener una estructura clara:

# %% [markdown]
# ```bash
# mi_proyecto/
# ├── data/              # Datos originales y procesados
# ├── notebooks/         # Análisis exploratorios
# ├── src/               # Código fuente del modelo
# ├── outputs/           # Resultados, figuras y modelos
# ├── requirements.txt   # Librerías necesarias
# ├── README.md          # Descripción del proyecto
# └── .gitignore         # Archivos a excluir del repo

# %% [markdown]
# ## 📌 1.4.5 Reproducibilidad en ciencia de datos

# %% [markdown]
# La reproducibilidad garantiza que otros puedan replicar tus resultados. Buenas prácticas:
#
# - Fijar versiones de librerías en `requirements.txt`:
#
# ```bash
# pip freeze > requirements.txt

# %% [markdown]
#     Usar entornos virtuales (venv, conda).
#
#     Documentar tu código y experimentos.
#
#     Subir notebooks limpios (sin celdas ejecutadas) o usar nbstripout.

# %% [markdown]
#     Puedes automatizar esto con herramientas como:
#
#     DVC: versionamiento de datos.
#
#     MLflow o Weights & Biases: tracking de experimentos.

# %% [markdown]
# ---
#
# ## ✅ Conclusión
#
# ```markdown
# Git y GitHub son esenciales para trabajar de forma profesional y colaborativa.
#
# - Facilitan el control de cambios, la colaboración, y la integración continua.
# - Una estructura bien organizada mejora la reproducibilidad y la escalabilidad de tus proyectos de IA.
#
# 💡 ¡Empieza usando Git desde tus notebooks hoy mismo!
