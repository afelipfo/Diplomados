# %% [markdown]
# # 🚀 Introducción a C++ para Ingeniería de Inteligencia Artificial
#
# Aunque Python es el lenguaje más utilizado en ciencia de datos e IA, **C++ sigue siendo una herramienta fundamental** cuando se requiere **mayor rendimiento, control de memoria o integración con hardware**.
#
# Este notebook aborda:
#
# - ¿Por qué aprender C++ como complemento a Python?
# - Comparación en términos de rendimiento.
# - Casos reales de uso en proyectos de IA y computación científica.

# %% [markdown]
# ## 🎯 ¿Por qué aprender C++?
#
# - Python es excelente para **prototipado rápido** y experimentación.
# - Sin embargo, **C++ ofrece mayor velocidad**, acceso directo a la memoria y más control sobre la ejecución.
# - Muchas librerías de alto rendimiento están escritas en C++ y tienen *bindings* en Python.
#
# ### Beneficios:
# - Optimización de partes críticas (hot spots) de código.
# - Desarrollo de simuladores físicos, motores de inferencia y controladores embebidos.
# - Posibilidad de crear extensiones para Python.
#
# > 💡 Aprender C++ permite desarrollar soluciones híbridas más eficientes.

# %% [markdown]
# ## ⚖️ Comparativa de rendimiento
#
# Python es interpretado y orientado a la productividad. C++ es compilado y orientado a la eficiencia.
#
# | Aspecto                  | Python                        | C++                           |
# |--------------------------|-------------------------------|-------------------------------|
# | Velocidad                | Media (interpretado)          | Alta (compilado a máquina)    |
# | Control de memoria       | Automático (garbage collector)| Manual / punteros inteligentes|
# | Sintaxis                 | Sencilla, de alto nivel       | Más compleja, bajo nivel      |
# | Prototipado rápido       | ✅                             | ❌                            |
# | Escalabilidad / rendimiento | ❌ Limitado                | ✅ Alta eficiencia             |
#
# ### Ejemplo simple (C++ vs Python):
#
# ```cpp
# // C++: suma de 1 a 1e8
# #include <iostream>
# #include <chrono>
# using namespace std;
#
# int main() {
#     auto start = chrono::high_resolution_clock::now();
#
#     long long suma = 0;
#     for (long long i = 1; i <= 1e8; ++i) {
#         suma += i;
#     }
#
#     auto end = chrono::high_resolution_clock::now();
#     cout << "Suma: " << suma << endl;
#     cout << "Tiempo: "
#          << chrono::duration_cast<chrono::milliseconds>(end - start).count()
#          << " ms" << endl;
#
#     return 0;
# }

# %% [markdown]
# ---
#
# ## 🧠 1.3 Casos de uso de C++ en IA y computación científica
#
# ```markdown
# ## 🧠 Casos de uso reales de C++ en IA
#
# ### 🔧 Backend de PyTorch
# - PyTorch está implementado mayoritariamente en C++ (ATen, LibTorch).
# - La API de Python llama funciones optimizadas escritas en C++.
#
# ### ⚙️ Motores de inferencia
# - ONNX Runtime, TensorRT y otros frameworks usan C++ para alta velocidad en producción.
# - Optimización para edge devices (Jetson, Raspberry Pi, etc.).
#
# ### 🧪 Simuladores físicos
# - Simuladores de robots (Gazebo, Isaac Sim) usan C++ por eficiencia en procesamiento de física en tiempo real.
#
# ### 🎮 Motores gráficos y IA en videojuegos
# - Unreal Engine y Unity permiten integrar C++ con lógica de IA para comportamientos en NPCs y entornos interactivos.
#
# ### 📦 Bibliotecas de soporte
# - Eigen: álgebra lineal.
# - OpenCV: procesamiento de imágenes.
# - Dlib: reconocimiento facial.
# - Ceres Solver: optimización no lineal.
#
# > 🧩 Muchas de estas bibliotecas pueden integrarse con Python mediante bindings como `pybind11`.

# %% [markdown]
# C++ no reemplaza a Python, pero lo complementa perfectamente cuando:
#
# - Se necesita rendimiento en tiempo real.
# - Se requiere control fino de memoria o ejecución.
# - Se desarrollan bibliotecas base para otros lenguajes.
#
# 💡 Dominar ambos lenguajes te convierte en un ingeniero de IA más completo y preparado para sistemas de producción.
